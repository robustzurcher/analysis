# %%
df = performance_dataframe()

# %%
measures = ["Maximin", "Minimax \n regret", "Subjective \n Bayes"]
strategies = [0.0, 0.1, 0.2, 0.3]
df_rank = print_generate_rankings(df, strategies, measures)
# Out:
# 0.0   -60708.900207
# 0.1   -60711.900676
# 0.2   -60722.939155
# 0.3   -60736.283266
# dtype: float64
# 0.3   -84148.951628
# 0.2   -84148.990075
# 0.1   -84149.048467
# 0.0   -84149.331915
# dtype: float64
# 0.1    549.477737
# 0.2    595.620952
# 0.0    598.898235
# 0.3    651.807170
# dtype: float64
# The order of subjective belief is [0.0 0.1 0.2 0.3]
# The order of max min is [0.3 0.2 0.1 0.0]
# The order of min max regret is [0.1 0.2 0.0 0.3]

# %%
df_rank
# Out:
#                     0.0 0.1 0.2 0.3
# Maximin               3   2   1   0
# Minimax \n regret     2   0   1   3
# Subjective \n Bayes   0   1   2   3

# %%
create_ranking_graph(df_rank)

# %%
compared_strat = 0.1
plot_performance_difference_matrix(df, compared_strat)

# %%
get_optimal_omega_maximin(df)
