# %% [markdown]
# # Figures for the urn example

# %%
mid_point = 0.4
lambda_robust = 0.9

# %%
create_plot_expected_payoff_func(mid_point, lambda_robust)

# %%
create_plot_risk_functions()

# %%
create_exp_payoff_plot_two_points(0.1, mid_point, lambda_robust)

# %%
create_rank_plot_urn()

# %%
create_optimal_lambda_plot()
