# %% [markdown]
# ## Calibration of ambiguity set

# %%
fig, ax = plt.subplots(1, 1)

ax.axis("equal")
ax.set_ylim([-1, 1])
ax.set_xlim([-1, 1])
ax.axis('off')

ax.add_artist(plt.Circle((0, 0), 0.6, fill=False))

ax.plot(-0.34, 0.3, marker='o', markersize=5, color="k")
ax.annotate(xy=[-0.38,0.2], text='$p_0$', fontsize=20)

ax.annotate(xy=[0.17,0.27], text=r'$\rho$', fontsize=20)

ax.plot(0.03, 0, marker='o', markersize=5, color="k")
ax.plot([0.04, 0.25], [0.01, 0.545], color='k', linestyle='--', linewidth=2)

ax.annotate(xy=[0,-0.15], text='$\hat{p}$', fontsize=20)
ax.annotate(xy=[-0.45,-0.3], text=r'$\{p : D_\phi(p \parallel \hat{p}) \leq \rho\}$', fontsize=20)




fig.savefig('{:}/fig-framework-ambiguity-set-calibration-sw'.format(DIR_FIGURES))

# %%
create_plot_1()

# %%
create_plot_2()

# %%
df = construct_performance()
df_regret = construct_regret(df)

# %%
report_decisions(df, df_regret)
# Out:
# Maximin: optimal
# Minimax: robust
# Bayes:   robust

# %%
expected_performance(df)

# %%
expected_regret(df_regret)

# %%
df = pd.DataFrame(data=[[0, 1], [1, 0], [1, 0]],
                  index=["Subjective Bayes", "Minimax regret", "Maximin"],
                  columns=["optimal", "robust"])
create_ranking_graph_illustrive(df)
