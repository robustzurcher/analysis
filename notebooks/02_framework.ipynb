# %% [markdown]
# ## Calibration of ambiguity set

# %%
create_plot_1()

# %%
create_plot_2()

# %%
df_perform = construct_performance()
df_regret = construct_regret(df_perform)

# %%
expected_performance(df_perform)

# %%
expected_regret(df_regret)

# %%
measures = ["Maximin", "Minimax \n regret", "Subjective \n Bayes"]
df_ranking = report_decisions(df_perform, df_regret, measures)
# Out:
# Maximin: as-if
# Minimax: robust
# Bayes:   robust

# %%
df_ranking
# Out:
#                      as-if  robust
# Maximin                  0       1
# Minimax \n regret        1       0
# Subjective \n Bayes      1       0

# %%
create_ranking_graph_illustrive(df_ranking)
