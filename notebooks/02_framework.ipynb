# %% [markdown]
# ## Calibration of ambiguity set

# %%
fig, ax = plt.subplots(1, 1)

ax.axis("equal")
ax.set_ylim([-1, 1])
ax.set_xlim([-1, 1])
ax.axis('off')

ax.add_artist(plt.Circle((0, 0), 0.6, fill=False))

ax.plot(-0.34, 0.3, marker='o', markersize=5, color="k")
ax.annotate(xy=[-0.38,0.2], s='$p_0$', fontsize=20)

ax.annotate(xy=[0.17,0.27], s=r'$\rho$', fontsize=20)

ax.plot(0.03, 0, marker='o', markersize=5, color="k")
ax.plot([0.04, 0.25], [0.01, 0.545], color='k', linestyle='--', linewidth=2)

ax.annotate(xy=[0,-0.15], s='$\hat{p}$', fontsize=20)
ax.annotate(xy=[-0.45,-0.3], s=r'$\{p : D_\phi(p \parallel \hat{p}) \leq \rho\}$', fontsize=20)




fig.savefig('{:}/fig-framework-ambiguity-set-calibration-sw'.format(DIR_FIGURES))
# Out:
# <ipython-input-1-432d698b194d>:11: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(xy=[-0.38,0.2], s='$p_0$', fontsize=20)
# <ipython-input-1-432d698b194d>:13: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(xy=[0.17,0.27], s=r'$\rho$', fontsize=20)
# <ipython-input-1-432d698b194d>:18: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(xy=[0,-0.15], s='$\hat{p}$', fontsize=20)
# <ipython-input-1-432d698b194d>:19: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(xy=[-0.45,-0.3], s=r'$\{p : D_\phi(p \parallel \hat{p}) \leq \rho\}$', fontsize=20)

# %%
from figures_framework import *

# %%
plot_performance()

# %%
df = pd.DataFrame(data=[[0, 1], [1, 0], [1, 0]],
                  index=["Subjective Bayes", "Minimax regret", "Maximin"],
                  columns=["optimal", "robust"])
create_ranking_graph_illustrive(df)
# Out:
# /home/peisenha/local/anaconda3/envs/ruspy_analysis/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
