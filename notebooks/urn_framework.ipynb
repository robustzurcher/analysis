# %%
np.random.seed(123)
n = 50
num_experiments = 10000
omega = 0.99
gridsize_sets = 1e-3
gridsize_probs = 1e-4
prob_grid = np.arange(gridsize_probs, 1, gridsize_probs)

# %%
worst_series = get_worsts_on_sample(n, gridsize_sets, omega)

# %%
get_loss_plot_with_bars(n, 0.4, worst_series)

# %%
p_1 = 0.4
p_2 = 0.1
df = expected_loss_df(n, p_1, p_2, worst_series)

# %%
plot_expected_loss_df(df)

# %%
exp_losses_robust, exp_losses_as_if = get_losses(
    prob_grid, num_experiments, n, worst_series
)

# %%
plot_risk_function(prob_grid, exp_losses_robust, exp_losses_as_if)

# %%
df_ranking = create_ranking_df(exp_losses_robust, exp_losses_as_if)

# %%
df_ranking
# Out:
#                      as-if  robust
# Minimax \n regret      1.0     0.0
# Subjective \n Bayes    1.0     0.0

# %%
create_ranking(df_ranking)
